# %%
import pandas as pd
df = pd.read_parquet("datasets/pre_computed_slopes_scores.parquet")
display(df)
# Out:
#                                                      title  _float_0  \
# 0                             ! .. عشان ما تنضربش على قفاك       NaN
# 1                                         !!شعراء إرهابيون       NaN
# 2        !búscalo! (look it up!): a quick reference gui...       NaN
# 3           !exacto!: a practical guide to spanish grammar       NaN
# 4          !feliz navidad: celebrating a mexican christmas       NaN
# ...                                                    ...       ...
# 1486019  ｍな女王様と××したいってばよ [m na jousama to xx shitai tte...       NaN
# 1486020                               ｍの劣情 [m no retsujou]       NaN
# 1486021                              ｓａｍｕｒａｉ　ｄｅｅｐｅｒ　ｋｙｏ（１）       NaN
# 1486022                                         ｘｂｌａｄｅ（１０）       NaN
# 1486023                             ｘｘｘアレルギー [xxx allergy]       NaN
#
#          _float_1  _float_2  _float_3  _float_4  _float_5  _float_6  _float_7  \
# 0             NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1             NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2             NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3             NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4             NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...           ...       ...       ...       ...       ...       ...       ...
# 1486019       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1486020       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1486021       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1486022       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1486023       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#          _float_8  ...      _lrc_127      _lrc_128      _lrc_129  \
# 0             NaN  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 1             NaN  ... -2.980232e-08 -2.980232e-08 -2.980232e-08
# 2             NaN  ... -5.960464e-08 -5.960464e-08 -5.960464e-08
# 3             NaN  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 4             NaN  ...           NaN           NaN           NaN
# ...           ...  ...           ...           ...           ...
# 1486019       NaN  ... -2.980232e-08 -2.980232e-08 -2.980232e-08
# 1486020       NaN  ...  2.980232e-08  2.980232e-08  2.980232e-08
# 1486021       NaN  ... -5.960464e-08 -5.960464e-08 -5.960464e-08
# 1486022       NaN  ... -5.960464e-08 -5.960464e-08 -5.960464e-08
# 1486023       NaN  ...  0.000000e+00  0.000000e+00  0.000000e+00
#
#              _lrc_130      _lrc_131  _lrc_0  _lrc_1  _lrc_2  _lrc_3  _lrc_4
# 0        0.000000e+00  0.000000e+00     NaN     NaN     NaN     NaN     NaN
# 1       -2.980232e-08 -2.980232e-08     NaN     NaN     NaN     NaN     NaN
# 2       -5.960464e-08 -5.960464e-08     NaN     NaN     NaN     NaN     NaN
# 3        0.000000e+00  0.000000e+00     NaN     NaN     NaN     NaN     NaN
# 4                 NaN           NaN     NaN     NaN     NaN     NaN     NaN
# ...               ...           ...     ...     ...     ...     ...     ...
# 1486019 -2.980232e-08 -2.980232e-08     NaN     NaN     NaN     NaN     NaN
# 1486020  2.980232e-08  2.980232e-08     NaN     NaN     NaN     NaN     NaN
# 1486021 -5.960464e-08 -5.960464e-08     NaN     NaN     NaN     NaN     NaN
# 1486022 -5.960464e-08 -5.960464e-08     NaN     NaN     NaN     NaN     NaN
# 1486023  0.000000e+00  0.000000e+00     NaN     NaN     NaN     NaN     NaN
#
# [1486024 rows x 265 columns]

# %%
price_df = pd.read_csv("datasets/Buchpreise_2009-2024.csv")

def comp_months(df):
    split_date = df['date'].str.split("/")
    df['year'] = pd.to_numeric(split_date.str[-1], errors='coerce', downcast='integer')

    df['month'] = pd.to_numeric(split_date.str[0], errors='coerce', downcast='integer')

    # Compute months since December 2006
    df['month'] = ((df['year'] - 2006) * 12) + (df['month'] - 12)

    return df

price_df = comp_months(price_df)
price_df = price_df.dropna(subset=['title'])
price_df = price_df[price_df['year'] < 2016]
price_df['month'] = price_df['month'].astype(int)


display(price_df)
display(price_df.dtypes)
# Out:
#         year                        title             author  \
# 0     2009.0             Olive Kitteridge   Elizabeth Strout
# 1     2010.0                      Tinkers       Paul Harding
# 2     2011.0  A Visit from the Goon Squad      Jennifer Egan
# 3     2013.0      The Orphan Master's Son       Adam Johnson
# 4     2014.0                The Goldfinch        Donna Tartt
# ...      ...                          ...                ...
# 1375  2009.0               Little Brother      Cory Doctorow
# 1376  2009.0                     Cauldron      Jack McDevitt
# 1377  2009.0                       Brasyl       Ian McDonald
# 1378  2009.0                 Making Money    Terry Pratchett
# 1379  2009.0                  Superpowers  David J. Schwartz
#
#                            price Shortlist/Longlist/Winner     ISBN-10  \
# 0     Pulitzer Prize for Fiction                    Winner  140006208X
# 1     Pulitzer Prize for Fiction                    Winner  1446455998
# 2     Pulitzer Prize for Fiction                    Winner  0231545401
# 3     Pulitzer Prize for Fiction                    Winner  0231557450
# 4     Pulitzer Prize for Fiction                    Winner  3656925348
# ...                          ...                       ...         ...
# 1375                Nebula Award                 Shortlist  1473231930
# 1376                Nebula Award                 Shortlist  1472203305
# 1377                Nebula Award                 Shortlist  0575087358
# 1378                Nebula Award                 Shortlist  1407034014
# 1379                Nebula Award                 Shortlist  1407013416
#
#            date       ISBN-13  month
# 0     4/20/2009  9.781400e+12     28
# 1     4/12/2010  9.781446e+12     40
# 2     4/18/2011  9.780232e+12     52
# 3     4/15/2013  9.780232e+12     76
# 4     4/14/2014  9.783657e+12     88
# ...         ...           ...    ...
# 1375   5/2/2009  9.781473e+12     29
# 1376   5/2/2009  9.781472e+12     29
# 1377   5/2/2009  9.780575e+12     29
# 1378   5/2/2009  9.781407e+12     29
# 1379   5/2/2009  9.781407e+12     29
#
# [563 rows x 9 columns]
# year                         float64
# title                         object
# author                        object
# price                         object
# Shortlist/Longlist/Winner     object
# ISBN-10                       object
# date                          object
# ISBN-13                      float64
# month                          int64
# dtype: object

# %%
#print(price_df[[price_df["price"] == "Österreichischer Buchpreis"]])

# %%
from sklearn.neighbors import NearestNeighbors
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

def find_matched_controls(winner_row, control_books, win_month, n_neighbors=50):
    """
    Find control books using kNN based on normalized pre-win reviews and transformed review slope.
    Handles NaN values by:
    - Returning empty results if the winner row contains NaNs.
    - Dropping rows with NaNs jointly in the control group.
    Scales features using MinMaxScaler within the same function.
    """
    win_month -= 1  # Exclude direct effects of winning the prize
    
    # Extract relevant columns
    winner_float_col = f'_float_{win_month}'
    winner_lrc_col = f'_lrc_{win_month}'

    # Check if the winner row contains NaNs in the relevant columns
    if pd.isna(winner_row[winner_float_col]) or pd.isna(winner_row[winner_lrc_col]):
        print("Winner row contains NaN values. Returning empty result.")
        return pd.DataFrame()  # Return an empty DataFrame

    # Drop rows with NaNs jointly in the control group
    control_books = control_books.dropna(subset=[winner_float_col, winner_lrc_col])

    # Extract features for controls
    control_features = control_books[[winner_float_col, winner_lrc_col]].values

    # Normalize features using MinMaxScaler (scaled to [0, 1])
    scaler = MinMaxScaler()
    control_features_scaled = scaler.fit_transform(control_features)

    # Scale the winner's features using the same scaler
    winner_features = np.array([
        winner_row[winner_float_col],  # Pre-win reviews (cumulative)
        winner_row[winner_lrc_col]     # LRC
    ]).reshape(1, -1)
    winner_features_scaled = scaler.transform(winner_features)

    # Fit kNN model on scaled features
    nn = NearestNeighbors(n_neighbors=n_neighbors, metric="euclidean").fit(control_features_scaled)
    _, indices = nn.kneighbors(winner_features_scaled)

    # Return matched controls
    return control_books.iloc[indices.flatten()]

# %%
import pandas as pd
import numpy as np
from dowhy import CausalModel

# Define columns
int_columns = [col for col in df.columns if col.startswith('_float_')]
slope_columns = [col for col in df.columns if col.startswith('_lrc_')]

def analyze_prize_impact(df, price_df, prize_name=None):
    """
    Analyze the impact of winning a prize on review counts using causal inference.
    Only important metrics (ATE, confidence intervals) are stored and printed.
    """
    # Filter winners
    winners = price_df[price_df['Shortlist/Longlist/Winner'] == 'Winner'].copy()
    winners['title'] = winners['title'].str.strip().str.lower()
    
    if prize_name:
        winners = winners[winners['price'] == prize_name]
    
    # Separate winners and controls
    winner_books = df[df['title'].isin(winners['title'])]
    control_books = df[~df['title'].isin(winners['title'])].copy()
    
    results = []
    
    for _, winner in winners.iterrows():
        title = winner['title']
        win_month = winner['month']
        
        # Skip if winner book not found
        if title not in winner_books['title'].values:
            print(f"Book '{title}' not found in dataset.")
            continue
        
        # Prepare winner's time series
        winner_row = winner_books[winner_books['title'] == title].iloc[0]
        winner_ts = pd.DataFrame({
            'date': range(len(int_columns)),
            'reviews': winner_row[int_columns].values
        })
        
        # Match controls using kNN
        matched_controls = find_matched_controls(winner_row, control_books, win_month)
        
        if matched_controls.empty:
            print(f"No matched controls found for book '{title}'.")
            continue
        
        # Combine winner and control data
        control_ts = pd.DataFrame({
            f'ctrl_reviews_{i}': matched_controls.iloc[i][int_columns].values
            for i in range(len(matched_controls))
        })
        analysis_df = pd.concat([winner_ts, control_ts], axis=1).dropna()
        
        # Validate columns
        valid_cols = [
            col for col in analysis_df.columns
            if analysis_df[col].nunique() > 1 and analysis_df[col].std() > 0
        ]
        analysis_df = analysis_df[valid_cols]
        
        if 'reviews' not in analysis_df.columns or len(analysis_df.columns) < 2:
            print(f"Insufficient valid data for book '{title}'.")
            continue
        
        # Define treatment variable
        analysis_df['treatment_dummy'] = (analysis_df['date'] >= win_month).astype(int)
        
        # Causal inference (reviews impact)
        try:
            print("starting inference")
            
            reviews_model = CausalModel(
                data=analysis_df,
                treatment='treatment_dummy',
                outcome='reviews',
                common_causes=[col for col in analysis_df.columns if col.startswith('ctrl_reviews')],
                time_variable='date'
            )
            identified_estimand = reviews_model.identify_effect()
            causal_estimate = reviews_model.estimate_effect(
                identified_estimand,
                method_name="backdoor.propensity_score_weighting",
                confidence_intervals=True
            )
            
            # Extract key metrics
            ate = causal_estimate.value  # Average Treatment Effect
            ci_low, ci_high = causal_estimate.get_confidence_intervals()
            # Print results
            print(f"Results for book '{title}':")
            print(f"  ATE: {ate:.4f}")
            print(f"  Confidence Interval: [{ci_low:.4f}, {ci_high:.4f}]")
            print("\n" + "-"*10 + "\n")
            
            # Store results
            results.append({
                'title': title,
                'ATE': ate,
                'CI_low': ci_low,
                'CI_high': ci_high
            })
        except Exception as e:
            print(f"Error analyzing book '{title}': {e}")
    
    return results

# %%
import json
# Get unique non-empty prizes
unique_prizes = price_df['price'].dropna().unique().tolist()
display(unique_prizes)

# Initialize master results dictionary
all_results = {}

# Run analysis for each prize
for prize in unique_prizes:
    try:
        print(f"Analyzing prize: {prize}")
        prize_results = analyze_prize_impact(
            df,
            price_df,
            prize_name=prize
        )
        
        # Convert results to a dictionary (key: book title)
        prize_results_dict = {result['title']: result for result in prize_results}
        
        # Save to master dictionary
        all_results[prize] = prize_results_dict
    except Exception as e:
        print(f"Error analyzing prize '{prize}': {e}")

# Save as JSON
with open('outcomes/prize_impact_results_scores.json', 'w') as f:
    json.dump(all_results, f, default=lambda x: float(x) if isinstance(x, np.float32) else x, indent=4)
# Out:
# ['Pulitzer Prize for Fiction',
#  'National Book Award',
#  'Hugo Award',
#  'Deutscher Buchpreis',
#  'Booker Prize',
#  'Literature Nobel Prize',
#  'Goodreads Choice Awards',
#  "Women's Prize for Fiction",
#  'National Book Award for Fiction',
#  'Nebula Award']
# Analyzing prize: Pulitzer Prize for Fiction
# starting inference
# Results for book 'olive kitteridge':
#   ATE: 0.1049
#   Confidence Interval: [-0.0849, 0.3243]
#
# ----------
#
# starting inference
# Results for book 'tinkers':
#   ATE: 0.3814
#   Confidence Interval: [0.3285, 0.4485]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'a visit from the goon squad':
#   ATE: -0.3904
#   Confidence Interval: [-0.4707, -0.3025]
#
# ----------
#
# starting inference
# Results for book 'the orphan master's son':
#   ATE: 0.0497
#   Confidence Interval: [-0.0099, 0.1202]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'the goldfinch':
#   ATE: -0.2128
#   Confidence Interval: [-0.2748, -0.1546]
#
# ----------
#
# starting inference
# Results for book 'all the light we cannot see':
#   ATE: -0.0523
#   Confidence Interval: [-0.0658, -0.0384]
#
# ----------
#
# Analyzing prize: National Book Award
# starting inference
# Results for book 'let the great world spin':
#   ATE: 0.0980
#   Confidence Interval: [0.0286, 0.1863]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'shine shine shine'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'the sense of an ending'.
# starting inference
# Results for book 'this is how you lose her':
#   ATE: -0.2580
#   Confidence Interval: [-0.6354, 0.2087]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'the goldfinch':
#   ATE: -0.2500
#   Confidence Interval: [-0.4327, -0.1554]
#
# ----------
#
# starting inference
# Results for book 'redeployment':
#   ATE: -0.2194
#   Confidence Interval: [-0.2747, -0.1452]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'between the world and me':
#   ATE: -0.2461
#   Confidence Interval: [-0.3728, -0.0970]
#
# ----------
#
# starting inference
# Results for book 'the underground railroad':
#   ATE: 1.7910
#   Confidence Interval: [1.5962, 2.0171]
#
# ----------
#
# Analyzing prize: Hugo Award
# starting inference
# Results for book 'the graveyard book':
#   ATE: -0.1222
#   Confidence Interval: [-0.1714, -0.0746]
#
# ----------
#
# starting inference
# Results for book 'the city & the city':
#   ATE: -0.0621
#   Confidence Interval: [-0.1084, -0.0188]
#
# ----------
#
# starting inference
# Results for book 'the windup girl':
#   ATE: 0.0153
#   Confidence Interval: [-0.1159, 0.1107]
#
# ----------
#
# Book 'blackout/all clear' not found in dataset.
# starting inference
# Results for book 'among others':
#   ATE: -0.1657
#   Confidence Interval: [-0.1910, -0.1450]
#
# ----------
#
# starting inference
# Results for book 'redshirts: a novel with three codas':
#   ATE: 0.1259
#   Confidence Interval: [0.1158, 0.1361]
#
# ----------
#
# Book 'ancillary justice' not found in dataset.
# starting inference
# Results for book 'the three body problem':
#   ATE: 0.9254
#   Confidence Interval: [0.8509, 1.0610]
#
# ----------
#
# Analyzing prize: Deutscher Buchpreis
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'du stirbst nicht'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'tauben fliegen auf'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'in zeiten des abnehmenden lichts'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'landgericht'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'das ungeheuer'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'kruso'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'die erfindung der roten armee fraktion durch einen manisch-depressiven teenager im sommer 1969'.
# Analyzing prize: Booker Prize
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'wolf hall'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'the finkler question'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'the sense of an ending'.
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'bring up the bodies':
#   ATE: -0.5648
#   Confidence Interval: [-0.7923, -0.4265]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'the luminaries'.
# starting inference
# Results for book 'the narrow road to the deep north':
#   ATE: -0.0000
#   Confidence Interval: [-0.0755, 0.0622]
#
# ----------
#
# starting inference
# Results for book 'a brief history of seven killings':
#   ATE: -0.0588
#   Confidence Interval: [-0.0807, -0.0375]
#
# ----------
#
# Analyzing prize: Literature Nobel Prize
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'the hunger angel'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'the fox was ever the hunter'.
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'the feast of the goat':
#   ATE: -0.0296
#   Confidence Interval: [-0.1208, 0.0736]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'conversation in the cathedral':
#   ATE: -0.0165
#   Confidence Interval: [-0.0631, 0.0473]
#
# ----------
#
# Book 'baltic spring' not found in dataset.
# starting inference
# Results for book 'the half-finished heaven':
#   ATE: -0.6335
#   Confidence Interval: [-0.6969, -0.5826]
#
# ----------
#
# starting inference
# Results for book 'red sorghum':
#   ATE: -0.3572
#   Confidence Interval: [-0.3901, -0.3252]
#
# ----------
#
# starting inference
# Results for book 'frog':
#   ATE: -0.0335
#   Confidence Interval: [-0.1359, 0.0446]
#
# ----------
#
# starting inference
# Results for book 'too much happiness':
#   ATE: 0.0904
#   Confidence Interval: [0.0800, 0.1019]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'the love of a good woman':
#   ATE: 0.1879
#   Confidence Interval: [0.1481, 0.2381]
#
# ----------
#
# starting inference
# Results for book 'dora bruder':
#   ATE: -0.4385
#   Confidence Interval: [-0.4822, -0.3961]
#
# ----------
#
# starting inference
# Results for book 'honeymoon':
#   ATE: -0.0012
#   Confidence Interval: [-0.0171, 0.0155]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'the unwomanly face of war'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'second-hand time'.
# Analyzing prize: Goodreads Choice Awards
# Book 'diary of a wimpy kid: dog days' not found in dataset.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'dead and gone'.
# starting inference
# Results for book 'the help':
#   ATE: -0.1305
#   Confidence Interval: [-0.1756, -0.0923]
#
# ----------
#
# starting inference
# Results for book 'batman: whatever happened to the caped crusader?':
#   ATE: -0.0303
#   Confidence Interval: [-0.2553, 0.2036]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'the girl who played with fire'.
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'columbine':
#   ATE: 0.0490
#   Confidence Interval: [0.0207, 0.0698]
#
# ----------
#
# Book 'an echo in the bone' not found in dataset.
# starting inference
# Results for book 'leviathan':
#   ATE: -0.1892
#   Confidence Interval: [-0.2374, -0.1420]
#
# ----------
#
# starting inference
# Results for book 'along for the ride':
#   ATE: 0.0754
#   Confidence Interval: [-0.0464, 0.1742]
#
# ----------
#
# starting inference
# Results for book 'the last song':
#   ATE: 0.2899
#   Confidence Interval: [0.0715, 0.4510]
#
# ----------
#
# starting inference
# Results for book 'blueberry girl':
#   ATE: -0.1177
#   Confidence Interval: [-0.2016, -0.0111]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'catching fire'.
# Book 'diary of a wimpy kid: the ugly truth' not found in dataset.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'towers of midnight'.
# starting inference
# Results for book 'room':
#   ATE: -0.0229
#   Confidence Interval: [-0.1532, 0.0717]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'the immortal life of henrietta lacks':
#   ATE: -0.0983
#   Confidence Interval: [-0.1153, -0.0798]
#
# ----------
#
# Book 'twilight: the graphic novel' not found in dataset.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'fall of giants'.
# starting inference
# Results for book 'the tudors':
#   ATE: 0.0335
#   Confidence Interval: [-0.2260, 0.2625]
#
# ----------
#
# Book 'bite me: a love story' not found in dataset.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'unbearable lightness'.
# Book 'the girl who kicked the hornets' nest' not found in dataset.
# starting inference
# Results for book 'the immortal life of henrietta lacks':
#   ATE: -0.0983
#   Confidence Interval: [-0.1128, -0.0822]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'come on all you ghosts'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'lover mine'.
# starting inference
# Results for book 'feed':
#   ATE: -0.0981
#   Confidence Interval: [-0.1136, -0.0774]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'mockingjay'.
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'before i fall':
#   ATE: -0.2653
#   Confidence Interval: [-0.3022, -0.2289]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'torment'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'dead in the family'.
# starting inference
# Results for book 'it's a book':
#   ATE: -0.0808
#   Confidence Interval: [-0.1888, 0.0653]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'the son of neptune'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'a dance with dragons'.
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book '1q84':
#   ATE: -0.0094
#   Confidence Interval: [-0.0980, 0.1210]
#
# ----------
#
# Book 'vampire academy: the graphic novel' not found in dataset.
# starting inference
# Results for book 'the paris wife':
#   ATE: -0.0921
#   Confidence Interval: [-0.1486, -0.0315]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'steve jobs':
#   ATE: 0.7801
#   Confidence Interval: [-0.1777, 1.5382]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'graveminder':
#   ATE: -0.1307
#   Confidence Interval: [-0.2447, -0.0251]
#
# ----------
#
# starting inference
# Results for book 'bossypants':
#   ATE: -0.1156
#   Confidence Interval: [-0.1557, -0.0772]
#
# ----------
#
# starting inference
# Results for book 'two kisses for maddy: a memoir of loss & love':
#   ATE: -0.4161
#   Confidence Interval: [-0.5149, -0.3425]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'smokin' seventeen'.
# Book 'the geeks shall inherit the earth' not found in dataset.
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'horoscopes for the dead':
#   ATE: -0.0269
#   Confidence Interval: [-0.0684, 0.0194]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'lover unleashed'.
# starting inference
# Results for book '11/22/63':
#   ATE: 0.0467
#   Confidence Interval: [-0.0970, 0.1355]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'divergent'.
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'where she went':
#   ATE: -0.3233
#   Confidence Interval: [-0.3763, -0.2682]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'my father's daughter'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'city of fallen angels'.
# Book 'shadowfever' not found in dataset.
# starting inference
# Results for book 'when i grow up':
#   ATE: 0.0507
#   Confidence Interval: [0.0141, 0.0791]
#
# ----------
#
# starting inference
# Results for book 'little princes: one man's promise to bring home the lost children of nepal':
#   ATE: -0.0649
#   Confidence Interval: [-0.0792, -0.0516]
#
# ----------
#
# starting inference
# Results for book 'the mark of athena':
#   ATE: -0.6101
#   Confidence Interval: [-0.7426, -0.5261]
#
# ----------
#
# Book 'the dark tower: the wind through the keyhole' not found in dataset.
# starting inference
# Results for book 'the casual vacancy':
#   ATE: 0.2217
#   Confidence Interval: [0.1230, 0.3167]
#
# ----------
#
# starting inference
# Results for book 'the walking dead, vol. 16: a larger world':
#   ATE: 0.1940
#   Confidence Interval: [0.0258, 0.3339]
#
# ----------
#
# starting inference
# Results for book 'the light between oceans':
#   ATE: -0.1146
#   Confidence Interval: [-0.1475, -0.0812]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'the twelve':
#   ATE: 0.0166
#   Confidence Interval: [-0.0250, 0.0525]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'let's pretend this never happened':
#   ATE: -0.2044
#   Confidence Interval: [-0.2439, -0.1660]
#
# ----------
#
# starting inference
# Results for book 'wild: from lost to found on the pacific crest trail':
#   ATE: -0.2185
#   Confidence Interval: [-0.3103, -0.1130]
#
# ----------
#
# starting inference
# Results for book 'gone girl':
#   ATE: -0.1849
#   Confidence Interval: [-0.2258, -0.1385]
#
# ----------
#
# starting inference
# Results for book 'quiet: the power of introverts in a world that can't stop talking':
#   ATE: -0.0292
#   Confidence Interval: [-0.0410, -0.0187]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'a thousand mornings'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'fifty shades freed'.
# starting inference
# Results for book 'the long earth':
#   ATE: -0.2392
#   Confidence Interval: [-0.4580, -0.0046]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'insurgent'.
# starting inference
# Results for book 'the fault in our stars':
#   ATE: -0.1596
#   Confidence Interval: [-0.1801, -0.1403]
#
# ----------
#
# starting inference
# Results for book 'the pioneer woman cooks: recipes from an accidental country girl':
#   ATE: 0.0019
#   Confidence Interval: [-0.0064, 0.0100]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'insurgent'.
# starting inference
# Results for book 'shadow of night':
#   ATE: 0.3685
#   Confidence Interval: [-0.0066, 0.7438]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'olivia and the fairy princesses':
#   ATE: -0.2073
#   Confidence Interval: [-0.6113, 0.0022]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'the house of hades':
#   ATE: -0.4527
#   Confidence Interval: [-0.6901, -0.2534]
#
# ----------
#
# starting inference
# Results for book 'the ocean at the end of the lane':
#   ATE: -0.1134
#   Confidence Interval: [-0.1543, -0.0703]
#
# ----------
#
# starting inference
# Results for book 'and the mountains echoed':
#   ATE: -0.0658
#   Confidence Interval: [-0.0795, -0.0502]
#
# ----------
#
# starting inference
# Results for book 'tangled':
#   ATE: 0.1948
#   Confidence Interval: [0.1816, 0.2099]
#
# ----------
#
# starting inference
# Results for book 'beautiful creatures':
#   ATE: 0.0904
#   Confidence Interval: [0.0589, 0.1210]
#
# ----------
#
# starting inference
# Results for book 'life after life':
#   ATE: -0.1116
#   Confidence Interval: [-0.1511, -0.0617]
#
# ----------
#
# starting inference
# Results for book 'jim henson: the biography':
#   ATE: -0.1746
#   Confidence Interval: [-0.2845, 0.0633]
#
# ----------
#
# starting inference
# Results for book 'doctor sleep':
#   ATE: 0.0927
#   Confidence Interval: [0.0099, 0.1930]
#
# ----------
#
# Book 'hyperbole & a half' not found in dataset.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'i am malala'.
# starting inference
# Results for book 'inferno':
#   ATE: 0.0168
#   Confidence Interval: [-0.0306, 0.0608]
#
# ----------
#
# starting inference
# Results for book 'the autistic brain: thinking across the spectrum':
#   ATE: 0.1876
#   Confidence Interval: [0.1030, 0.2760]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'the fall of arthur':
#   ATE: -0.6170
#   Confidence Interval: [-0.7477, -0.4719]
#
# ----------
#
# Book 'lover at last' not found in dataset.
# starting inference
# Results for book 'maddaddam':
#   ATE: 0.0180
#   Confidence Interval: [-0.0964, 0.1363]
#
# ----------
#
# starting inference
# Results for book 'allegiant':
#   ATE: -0.8921
#   Confidence Interval: [-1.0399, -0.7443]
#
# ----------
#
# starting inference
# Results for book 'eleanor & park':
#   ATE: -0.0822
#   Confidence Interval: [-0.0939, -0.0673]
#
# ----------
#
# starting inference
# Results for book 'tequila mockingbird: cocktails with a literary twist':
#   ATE: 0.2899
#   Confidence Interval: [0.1633, 0.3966]
#
# ----------
#
# starting inference
# Results for book 'cold days':
#   ATE: -0.0855
#   Confidence Interval: [-0.1443, -0.0308]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'the day the crayons quit':
#   ATE: -0.0817
#   Confidence Interval: [-0.1499, 0.0259]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'the blood of olympus':
#   ATE: -0.1931
#   Confidence Interval: [-0.3118, -0.0194]
#
# ----------
#
# starting inference
# Results for book 'the book of life':
#   ATE: -0.1345
#   Confidence Interval: [-0.1770, -0.0988]
#
# ----------
#
# starting inference
# Results for book 'landline':
#   ATE: -0.1974
#   Confidence Interval: [-0.2275, -0.1747]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'red rising':
#   ATE: -0.3220
#   Confidence Interval: [-0.5362, -0.1341]
#
# ----------
#
# Book 'serenity: leaves on the wind' not found in dataset.
# starting inference
# Results for book 'all the light we cannot see':
#   ATE: -0.0562
#   Confidence Interval: [-0.0659, -0.0461]
#
# ----------
#
# starting inference
# Results for book 'the romanov sisters':
#   ATE: -0.4330
#   Confidence Interval: [-0.5906, -0.3660]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'prince lestat'.
# starting inference
# Results for book 'yes please':
#   ATE: -0.1045
#   Confidence Interval: [-0.1707, -0.0490]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'this star won't go out':
#   ATE: -0.3107
#   Confidence Interval: [-0.4165, -0.1828]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'mr. mercedes'.
# Book 'the opposite of loneliness' not found in dataset.
# starting inference
# Results for book 'lullabies':
#   ATE: -0.7503
#   Confidence Interval: [-1.0902, -0.3448]
#
# ----------
#
# starting inference
# Results for book 'written in my own heart's blood':
#   ATE: -0.2991
#   Confidence Interval: [-0.4150, -0.1389]
#
# ----------
#
# starting inference
# Results for book 'the martian':
#   ATE: -0.0766
#   Confidence Interval: [-0.1027, -0.0457]
#
# ----------
#
# Book 'city of heavenly fire' not found in dataset.
# starting inference
# Results for book 'we were liars':
#   ATE: -0.0381
#   Confidence Interval: [-0.0761, -0.0012]
#
# ----------
#
# starting inference
# Results for book '#girlboss':
#   ATE: 0.1734
#   Confidence Interval: [-0.2001, 0.3652]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'make it ahead: a barefoot contessa cookbook'.
# Book 'the pigeon needs a bath! (i do not!)' not found in dataset.
# Book 'the sword of summer' not found in dataset.
# Book 'trigger warning: short fictions & disturbances' not found in dataset.
# starting inference
# Results for book 'go set a watchman':
#   ATE: 0.0384
#   Confidence Interval: [-0.0347, 0.1079]
#
# ----------
#
# starting inference
# Results for book 'red queen':
#   ATE: 0.2712
#   Confidence Interval: [0.1929, 0.3505]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'saga, volume 4'.
# starting inference
# Results for book 'the nightingale':
#   ATE: -0.0319
#   Confidence Interval: [-0.0412, -0.0211]
#
# ----------
#
# starting inference
# Results for book 'dead wake: the last crossing of the lusitania':
#   ATE: -0.0686
#   Confidence Interval: [-0.0864, -0.0479]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'saint odd'.
# starting inference
# Results for book 'why not me?':
#   ATE: -0.1355
#   Confidence Interval: [-0.1764, -0.0941]
#
# ----------
#
# starting inference
# Results for book 'a work in progress':
#   ATE: -0.1879
#   Confidence Interval: [-0.2164, -0.1605]
#
# ----------
#
# starting inference
# Results for book 'the girl on the train':
#   ATE: -0.0842
#   Confidence Interval: [-0.1072, -0.0584]
#
# ----------
#
# starting inference
# Results for book 'modern romance: an investigation':
#   ATE: -0.1571
#   Confidence Interval: [-0.2266, -0.0810]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'the dogs i have kissed'.
# starting inference
# Results for book 'confess':
#   ATE: -0.0702
#   Confidence Interval: [-0.0835, -0.0557]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'golden son':
#   ATE: -0.1193
#   Confidence Interval: [-0.1960, -0.0511]
#
# ----------
#
# Book 'queen of shadows' not found in dataset.
# starting inference
# Results for book 'all the bright places':
#   ATE: -0.0401
#   Confidence Interval: [-0.0468, -0.0333]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'the pioneer woman cooks: dinnertime'.
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'the day the crayons came home':
#   ATE: -0.1419
#   Confidence Interval: [-0.2157, -0.0807]
#
# ----------
#
# starting inference
# Results for book 'beneath the surface: killer whales, seaworld, and the truth beyond blackfish':
#   ATE: -0.0529
#   Confidence Interval: [-0.0925, -0.0138]
#
# ----------
#
# Analyzing prize: Women's Prize for Fiction
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'home':
#   ATE: 0.6252
#   Confidence Interval: [0.4638, 0.8182]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'the lacuna':
#   ATE: 0.0824
#   Confidence Interval: [0.0222, 0.1218]
#
# ----------
#
# starting inference
# Results for book 'the tiger's wife':
#   ATE: -0.1163
#   Confidence Interval: [-0.2243, 0.0163]
#
# ----------
#
# starting inference
# Results for book 'the song of achilles':
#   ATE: -0.0480
#   Confidence Interval: [-0.1090, 0.0064]
#
# ----------
#
# starting inference
# Results for book 'may we be forgiven':
#   ATE: -0.0856
#   Confidence Interval: [-0.2227, 0.1434]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'a girl is a half-formed thing':
#   ATE: -0.5628
#   Confidence Interval: [-0.6960, -0.4109]
#
# ----------
#
# starting inference
# Results for book 'how to be both':
#   ATE: -0.0843
#   Confidence Interval: [-0.2732, 0.0754]
#
# ----------
#
# Analyzing prize: National Book Award for Fiction
# starting inference
# Results for book 'let the great world spin':
#   ATE: 0.0826
#   Confidence Interval: [0.0048, 0.1719]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'lord of misrule'.
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'salvage the bones'.
# starting inference
# Results for book 'the round house':
#   ATE: 0.2006
#   Confidence Interval: [-0.4114, 0.5962]
#
# ----------
#
# starting inference
# /home/matthias/.local/lib/python3.10/site-packages/dowhy/causal_estimators/propensity_score_weighting_estimator.py:245: RuntimeWarning: invalid value encountered in scalar divide
#   est = data["d_y"].sum() / sum_dy_weights - data["dbar_y"].sum() / sum_dbary_weights
# Results for book 'the good lord bird':
#   ATE: -0.1918
#   Confidence Interval: [-0.4353, 0.1553]
#
# ----------
#
# starting inference
# Results for book 'redeployment':
#   ATE: -0.1682
#   Confidence Interval: [-0.2282, -0.1075]
#
# ----------
#
# Winner row contains NaN values. Returning empty result.
# No matched controls found for book 'fortune smiles'.
# Analyzing prize: Nebula Award
# starting inference
# Results for book 'annihilation':
#   ATE: 0.4816
#   Confidence Interval: [0.2924, 0.6365]
#
# ----------
#
# Book 'ancillary justice' not found in dataset.
# starting inference
# Results for book '2312':
#   ATE: -0.0175
#   Confidence Interval: [-0.0257, -0.0092]
#
# ----------
#
# starting inference
# Results for book 'among others':
#   ATE: -0.2221
#   Confidence Interval: [-0.2598, -0.1695]
#
# ----------
#
# Book 'blackout / all clear' not found in dataset.
# starting inference
# Results for book 'the windup girl':
#   ATE: 0.0303
#   Confidence Interval: [-0.1571, 0.1902]
#
# ----------
#
# starting inference
# Results for book 'powers':
#   ATE: -0.6255
#   Confidence Interval: [-0.6708, -0.5933]
#
# ----------
